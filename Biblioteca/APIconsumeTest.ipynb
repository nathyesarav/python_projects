# %% [markdown]
#                                         Consumo de APIs - Resultado en tabla plana

# %% [markdown]
# Test:
#
# 1.- Consumir la API http://numbersapi.com/1..10
#
# 2.- Crear un dataFrame con los 1000 primeros números y descripciones
#
# 3.- Grabar la tabla en formato CSV
#
# 4.- Crear nueva columna con la longitud de la descripcion
#
# 5.- Mostrar en un histograma la distribución de longitudes de descripción

# %%
#__IMPORTAMOS TODAS LAS LIBRERIAS NECESARIAS__
import pandas as pd
import csv
import requests
import re
import ast
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import sys
import numpy as np

# %%
# 1.- Consumir la API http://numbersapi.com/1..10
APIurl = "http://numbersapi.com/"
list = []
for i in range(1,11):
    APIurlFor = APIurl+str((i*100)-99)+".."+str(i*100)
    APIresp = requests.get(APIurlFor)
    x = ast.literal_eval(APIresp.text)
    list.append(pd.DataFrame([[key, x[key]] for key in x.keys()], columns=['Number', 'Description']))
df = pd.concat(list)
df
# Out:
#    Number                                        Description
# 0       1           1 is the number of dimensions of a line.
# 1       2  2 is the number of stars in a binary star syst...
# 2       3  3 is the cost in cents to make a $1 bill in th...
# 3       4  4 is the number of characters in a canonical f...
# 4       5             5 is the number of dots in a quincunx.
# 5       6  6 is the number of feet below ground level a c...
# 6       7          7 is the number of colors of the rainbow.
# 7       8       8 is the number of legs that arachnids have.
# 8       9  9 is the number of innings in a regulation, no...
# 9      10           10 is the Number of dots in a tetractys.
# 10     11  11 is the number of sides on the Canadian one-...
# 11     12              12 is the number of months in a year.
# 12     13  13 is the number of colonies that formed the U...
# 13     14  14 is the minimum age at which one can work in...
# 14     15  15 is the length in miles of a train of boxcar...
# 15     16  16 is the number of teams that qualified for t...
# 16     17  17 is the number of flames emanating from the ...
# 17     18  18 is the number of colors the labels for Cray...
# 18     19        19 is the number of years in 235 lunations.
# 19     20  20 is the number of questions in the popular p...
# 20     21  21 is the number of points required to win a g...
# 21     22  22 is the number of letters in the Hebrew alph...
# 22     23  23 is the number of crosses on Calvary in the ...
# 23     24  24 is the number of bits a computer needs to r...
# 24     25  25 is the number of years of marriage marked i...
# 25     26  26 is the number of miles in a marathon rounde...
# 26     27  27 is the total number of letters in the Spani...
# 27     28  28 is the number worn by the Clemson Tigers' r...
# 28     29  29 is the highest possible score in a hand of ...
# 29     30  30 is the number of hours of the longest kiss ...
# ..    ...                                                ...
# 70    971                    971 is an uninteresting number.
# 71    972                            972 is a boring number.
# 72    973  973 is a number for which we're missing a fact...
# 73    974                            974 is a boring number.
# 74    975  975 is a number for which we're missing a fact...
# 75    976                            976 is a boring number.
# 76    977                     977 is an unremarkable number.
# 77    978                    978 is an uninteresting number.
# 78    979                            979 is a boring number.
# 79    980                    980 is an uninteresting number.
# 80    981                            981 is a boring number.
# 81    982                    982 is an uninteresting number.
# 82    983                            983 is a boring number.
# 83    984                     984 is an unremarkable number.
# 84    985                            985 is a boring number.
# 85    986                            986 is a boring number.
# 86    987                            987 is a boring number.
# 87    988                            988 is a boring number.
# 88    989  989 is a number for which we're missing a fact...
# 89    990  990 is a number for which we're missing a fact...
# 90    991  991 is a number for which we're missing a fact...
# 91    992                     992 is an unremarkable number.
# 92    993                     993 is an unremarkable number.
# 93    994                     994 is an unremarkable number.
# 94    995                            995 is a boring number.
# 95    996                    996 is an uninteresting number.
# 96    997                     997 is an unremarkable number.
# 97    998  998 is a number for which we're missing a fact...
# 98    999  999 is a number for which we're missing a fact...
# 99   1000  1000 is the number of elephants it took to bri...
#
# [1000 rows x 2 columns]

# %%
# Rename dataFrame columns
df.rename( columns={"Number" :'numero'}, inplace=True)
df.rename( columns={"Description" :'descripcion'}, inplace=True)

# Convert string to float
print (df.dtypes)
df.numero = df.numero.astype(float)
print (df.dtypes)
# Out:
# numero         object
# descripcion    object
# dtype: object
# numero         float64
# descripcion     object
# dtype: object

# %%
lenDescrip = []
for i in df['descripcion']:
    lenDescrip.append(len(i))
lenDescrip
# Out:
# [40,
#  129,
#  62,
#  77,
#  38,
#  76,
#  41,
#  44,
#  70,
#  40,
#  98,
#  37,
#  59,
#  63,
#  108,
#  178,
#  88,
#  66,
#  43,
#  73,
#  94,
#  51,
#  78,
#  111,
#  77,
#  78,
#  87,
#  78,
#  66,
#  119,
#  56,
#  78,
#  73,
#  93,
#  66,
#  90,
#  93,
#  148,
#  59,
#  121,
#  100,
#  45,
#  103,
#  57,
#  60,
#  38,
#  109,
#  45,
#  85,
#  58,
#  36,
#  48,
#  73,
#  81,
#  116,
#  96,
#  85,
#  81,
#  60,
#  64,
#  73,
#  63,
#  79,
#  89,
#  92,
#  86,
#  40,
#  68,
#  83,
#  69,
#  120,
#  56,
#  76,
#  36,
#  42,
#  34,
#  35,
#  55,
#  91,
#  112,
#  94,
#  58,
#  35,
#  36,
#  36,
#  94,
#  161,
#  60,
#  66,
#  56,
#  66,
#  81,
#  37,
#  41,
#  118,
#  45,
#  102,
#  45,
#  68,
#  87,
#  78,
#  50,
#  52,
#  112,
#  59,
#  49,
#  57,
#  69,
#  39,
#  251,
#  57,
#  51,
#  68,
#  106,
#  70,
#  187,
#  66,
#  51,
#  57,
#  78,
#  59,
#  54,
#  71,
#  67,
#  73,
#  86,
#  85,
#  155,
#  113,
#  57,
#  53,
#  47,
#  126,
#  94,
#  90,
#  96,
#  76,
#  70,
#  118,
#  125,
#  89,
#  44,
#  58,
#  40,
#  42,
#  78,
#  102,
#  100,
#  81,
#  69,
#  60,
#  64,
#  90,
#  67,
#  90,
#  72,
#  94,
#  114,
#  39,
#  102,
#  63,
#  103,
#  69,
#  65,
#  185,
#  49,
#  143,
#  78,
#  85,
#  114,
#  60,
#  120,
#  48,
#  134,
#  141,
#  79,
#  89,
#  55,
#  55,
#  73,
#  69,
#  93,
#  59,
#  62,
#  85,
#  71,
#  67,
#  45,
#  48,
#  48,
#  78,
#  71,
#  68,
#  67,
#  66,
#  72,
#  61,
#  76,
#  125,
#  111,
#  99,
#  48,
#  59,
#  104,
#  52,
#  45,
#  47,
#  57,
#  62,
#  72,
#  42,
#  69,
#  63,
#  116,
#  65,
#  145,
#  42,
#  90,
#  31,
#  45,
#  65,
#  155,
#  31,
#  90,
#  85,
#  90,
#  167,
#  31,
#  92,
#  38,
#  58,
#  31,
#  90,
#  90,
#  173,
#  23,
#  90,
#  23,
#  52,
#  65,
#  31,
#  77,
#  34,
#  23,
#  156,
#  31,
#  30,
#  72,
#  30,
#  101,
#  116,
#  23,
#  30,
#  90,
#  61,
#  55,
#  23,
#  23,
#  31,
#  31,
#  54,
#  23,
#  90,
#  30,
#  31,
#  30,
#  40,
#  30,
#  23,
#  53,
#  90,
#  23,
#  71,
#  23,
#  30,
#  141,
#  30,
#  30,
#  30,
#  31,
#  30,
#  23,
#  90,
#  31,
#  61,
#  31,
#  30,
#  23,
#  90,
#  90,
#  90,
#  90,
#  31,
#  90,
#  123,
#  23,
#  30,
#  90,
#  31,
#  70,
#  30,
#  23,
#  30,
#  92,
#  31,
#  31,
#  30,
#  31,
#  90,
#  23,
#  23,
#  23,
#  114,
#  90,
#  90,
#  23,
#  30,
#  23,
#  30,
#  30,
#  90,
#  30,
#  31,
#  31,
#  90,
#  23,
#  23,
#  113,
#  90,
#  31,
#  30,
#  23,
#  30,
#  96,
#  23,
#  54,
#  90,
#  90,
#  23,
#  90,
#  23,
#  23,
#  126,
#  23,
#  31,
#  30,
#  23,
#  23,
#  31,
#  100,
#  30,
#  126,
#  23,
#  30,
#  30,
#  90,
#  23,
#  30,
#  30,
#  80,
#  62,
#  90,
#  30,
#  85,
#  58,
#  41,
#  31,
#  90,
#  31,
#  30,
#  90,
#  30,
#  30,
#  23,
#  90,
#  30,
#  30,
#  23,
#  31,
#  30,
#  23,
#  90,
#  103,
#  109,
#  31,
#  68,
#  31,
#  23,
#  90,
#  86,
#  90,
#  90,
#  30,
#  23,
#  23,
#  77,
#  31,
#  30,
#  90,
#  112,
#  23,
#  30,
#  31,
#  86,
#  23,
#  90,
#  30,
#  90,
#  90,
#  31,
#  90,
#  23,
#  31,
#  30,
#  31,
#  90,
#  30,
#  87,
#  30,
#  90,
#  90,
#  30,
#  31,
#  90,
#  23,
#  30,
#  30,
#  23,
#  23,
#  90,
#  23,
#  58,
#  101,
#  23,
#  30,
#  23,
#  30,
#  30,
#  90,
#  96,
#  55,
#  90,
#  31,
#  31,
#  31,
#  90,
#  90,
#  30,
#  90,
#  52,
#  115,
#  23,
#  31,
#  23,
#  30,
#  90,
#  30,
#  31,
#  31,
#  90,
#  23,
#  23,
#  57,
#  92,
#  31,
#  90,
#  31,
#  23,
#  90,
#  71,
#  90,
#  30,
#  23,
#  30,
#  31,
#  90,
#  90,
#  23,
#  30,
#  120,
#  30,
#  90,
#  90,
#  31,
#  90,
#  23,
#  30,
#  30,
#  31,
#  92,
#  31,
#  31,
#  118,
#  90,
#  90,
#  92,
#  90,
#  90,
#  90,
#  106,
#  23,
#  31,
#  31,
#  30,
#  31,
#  23,
#  90,
#  31,
#  23,
#  31,
#  64,
#  31,
#  31,
#  23,
#  90,
#  23,
#  30,
#  30,
#  90,
#  90,
#  90,
#  23,
#  30,
#  90,
#  64,
#  23,
#  90,
#  30,
#  31,
#  90,
#  31,
#  30,
#  90,
#  23,
#  90,
#  124,
#  30,
#  79,
#  90,
#  31,
#  23,
#  23,
#  90,
#  23,
#  23,
#  30,
#  23,
#  23,
#  30,
#  116,
#  31,
#  31,
#  31,
#  30,
#  52,
#  90,
#  31,
#  23,
#  23,
#  31,
#  30,
#  112,
#  90,
#  90,
#  23,
#  30,
#  31,
#  30,
#  30,
#  30,
#  30,
#  30,
#  30,
#  30,
#  30,
#  30,
#  31,
#  31,
#  31,
#  90,
#  23,
#  23,
#  23,
#  90,
#  90,
#  90,
#  54,
#  90,
#  90,
#  31,
#  90,
#  23,
#  90,
#  23,
#  23,
#  90,
#  31,
#  23,
#  23,
#  124,
#  30,
#  23,
#  31,
#  90,
#  23,
#  23,
#  90,
#  23,
#  23,
#  23,
#  30,
#  90,
#  127,
#  119,
#  23,
#  23,
#  90,
#  30,
#  23,
#  31,
#  23,
#  31,
#  23,
#  90,
#  30,
#  96,
#  30,
#  30,
#  23,
#  30,
#  23,
#  30,
#  31,
#  31,
#  90,
#  31,
#  31,
#  23,
#  30,
#  30,
#  31,
#  23,
#  90,
#  90,
#  23,
#  31,
#  30,
#  31,
#  68,
#  30,
#  30,
#  30,
#  31,
#  23,
#  31,
#  30,
#  31,
#  30,
#  90,
#  30,
#  30,
#  31,
#  30,
#  31,
#  23,
#  31,
#  31,
#  90,
#  23,
#  31,
#  31,
#  30,
#  31,
#  30,
#  30,
#  23,
#  90,
#  90,
#  31,
#  23,
#  23,
#  31,
#  30,
#  90,
#  31,
#  90,
#  23,
#  31,
#  90,
#  30,
#  90,
#  31,
#  84,
#  30,
#  125,
#  31,
#  31,
#  30,
#  90,
#  23,
#  30,
#  31,
#  23,
#  23,
#  23,
#  30,
#  30,
#  23,
#  90,
#  23,
#  23,
#  85,
#  90,
#  62,
#  23,
#  23,
#  90,
#  23,
#  31,
#  46,
#  30,
#  23,
#  23,
#  90,
#  23,
#  23,
#  23,
#  23,
#  123,
#  30,
#  31,
#  23,
#  31,
#  30,
#  90,
#  31,
#  90,
#  30,
#  23,
#  30,
#  90,
#  90,
#  90,
#  30,
#  23,
#  31,
#  90,
#  90,
#  87,
#  30,
#  30,
#  23,
#  23,
#  31,
#  107,
#  23,
#  31,
#  23,
#  90,
#  90,
#  90,
#  23,
#  23,
#  23,
#  23,
#  30,
#  23,
#  90,
#  23,
#  23,
#  31,
#  31,
#  90,
#  30,
#  30,
#  31,
#  90,
#  31,
#  30,
#  90,
#  30,
#  23,
#  90,
#  30,
#  23,
#  90,
#  23,
#  90,
#  90,
#  23,
#  31,
#  30,
#  90,
#  30,
#  31,
#  90,
#  31,
#  31,
#  30,
#  90,
#  30,
#  30,
#  23,
#  31,
#  30,
#  23,
#  30,
#  30,
#  31,
#  30,
#  31,
#  23,
#  23,
#  23,
#  23,
#  23,
#  90,
#  90,
#  31,
#  23,
#  23,
#  23,
#  31,
#  31,
#  90,
#  23,
#  30,
#  31,
#  30,
#  90,
#  23,
#  31,
#  23,
#  31,
#  90,
#  90,
#  30,
#  30,
#  31,
#  31,
#  30,
#  90,
#  90,
#  31,
#  23,
#  30,
#  31,
#  31,
#  30,
#  52,
#  30,
#  90,
#  90,
#  30,
#  23,
#  90,
#  23,
#  31,
#  30,
#  30,
#  31,
#  30,
#  23,
#  31,
#  30,
#  30,
#  30,
#  30,
#  23,
#  30,
#  23,
#  23,
#  23,
#  30,
#  30,
#  30,
#  90,
#  30,
#  30,
#  30,
#  23,
#  30,
#  90,
#  30,
#  23,
#  90,
#  23,
#  23,
#  90,
#  31,
#  23,
#  23,
#  30,
#  30,
#  90,
#  30,
#  31,
#  90,
#  23,
#  31,
#  23,
#  90,
#  31,
#  31,
#  31,
#  23,
#  31,
#  31,
#  90,
#  90,
#  81,
#  30,
#  31,
#  23,
#  23,
#  23,
#  30,
#  30,
#  31,
#  90,
#  30,
#  30,
#  23,
#  23,
#  31,
#  90,
#  90,
#  23,
#  31,
#  90,
#  90,
#  31,
#  30,
#  30,
#  30,
#  90,
#  23,
#  90,
#  90,
#  30,
#  90,
#  31,
#  30,
#  30,
#  30,
#  23,
#  90,
#  30,
#  23,
#  31,
#  31,
#  23,
#  31,
#  31,
#  30,
#  31,
#  23,
#  30,
#  90,
#  23,
#  31,
#  90,
#  31,
#  30,
#  90,
#  30,
#  90,
#  30,
#  30,
#  31,
#  31,
#  23,
#  90,
#  23,
#  90,
#  23,
#  30,
#  31,
#  23,
#  31,
#  23,
#  31,
#  23,
#  30,
#  23,
#  23,
#  23,
#  23,
#  90,
#  90,
#  90,
#  30,
#  30,
#  30,
#  23,
#  31,
#  30,
#  90,
#  90,
#  116]

# %%
plt.style.use('ggplot')
plt.hist(lenDescrip, bins=10)
plt.show()

# %%
plt.hist(lenDescrip, bins=20)
plt.show()

# %%
# Grabamos el resultado como CSV separado por comas
CSVfilename = "numbers1000.csv"
df.to_csv(CSVfilename, index=False)
