# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Pairplot del dataset!
sns.pairplot(data_spotify)
#GGPLOT
ggplot(data=mpg)+
  geom_point(mapping = aes(x=cty,y=hwy),
             color="red",
             shape=2,
             size=4,
             fill="salmon")
# Barras
ggplot(data=mpg)+
  geom_bar(mapping = aes(x=drv))
# Load ggplot2
library("ggplot2")
# Scatter plot
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width)) +
  geom_point(aes(color = Species)) +
  scale_color_viridis_d() +
  theme_minimal()
plt.plot(df)
plt.show()
#Spark
# !pip install findspark
import findspark
findspark.init()

# %%
# Función que me devuelva todos los resultados que acabamos de obtener, para los países en una lista que le pasemos?
def names(list):    
names(paises)
names(paises, 'USA')
def names(list, pais):    
    if pais in list:
        print(pais)
    print('\n')           
def stats(list):    
    for pais in list:
        print(pais)
        print(data[data['COUNTRY']== pais]['SALES'].describe())
    stats(paises)
