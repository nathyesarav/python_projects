# %% [markdown]
# # Data Science Junior

# %% [markdown]
# ***
#
# ## Épica: Construir vuestro perfil de científico de datos

# %% [markdown]
# ### User Storie 3
# Averigua cuál es el salario medio de un Data Scientist Junior en España y cuál es en Europa ó USA (por ejemplo, en Londres). Calcula el salario en tres formatos:
#
#  - Total anual
#  - Mensual
#  - Por hora de trabajo

# %% [markdown]
# ### España
# Anual:
# 25.000 - 35000 €
# Mensual:
# Por hora de trabajo:

# %% [markdown]
# España:
# Sueldo bruto/año
# 25.000,00 €
#
# Paga extra neta
# 1.515,71 €
# Porcentaje de I.R.P.F./mes
# 15,12 %
# Total I.R.P.F./año
# 3780 €
# Total cuotas a la S.S.
# 1762,5 €
# Sueldo neto/año
# 19.457,5 €
#
# Francia:
# El importe del salario mínimo (SMIC) está fijado:
# Mensual (con 35 horas semanales):
#     - Bruto: 1.678,0 euros
#     - Neto: 1.329,06 euros
# Hora:
#     - Bruto: 11,07 euros
#     - Neto: 8,76 euros
#
# 	España		Francia		Italia		Dinamarca		Austria		USA		Dubai
# 	Bruto	Neto	Bruto	Neto	Bruto	Neto	Bruto	Neto	Bruto	Neto	Bruto	Neto	Bruto	Neto
# Anual	25.000,00 €	19.457,50 €	39.971,00 €	31.896,00 €	32.064,00 €		60.750,00 €		40.000,00 €		65.000,00 €	55.250,00 €	50.000,00 €	3.920.904
# Mensual	2.083,30 €	1.621,00 €	3.356,00 €	2.658,00 €	2.672,00 €		5.063,00 €		4.666,00 €		5.416,67 €	4.604,17 €		3.267,42 €
# Por hora	12.827 €	9.983 €	22.144 €	17.521 €		12.000 €		17.481 €		9.762 €	33,85 €	28,78 €

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Fuente: https://economia3.com/2021/08/13/457744-salario-medio-y-salario-minimo-interprofesional-de-las-10-principales-economias-de-la-union-europea/
