# %%
import pandas as pd

# %%
df = pd.read_csv('ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.sort_values('salary')
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 238         238       2021               EN              FT
# 185         185       2021               MI              FT
# 15           15       2020               MI              FT
# 124         124       2021               EN              PT
# 196         196       2021               EN              FT
# ..          ...        ...              ...             ...
# 285         285       2021               SE              FT
# 137         137       2021               MI              FT
# 7             7       2020               MI              FT
# 102         102       2021               MI              FT
# 177         177       2021               MI              FT
#
#                 job_title    salary salary_currency  salary_in_usd  \
# 238        Data Scientist      4000             USD           4000
# 185         Data Engineer      4000             USD           4000
# ...

# %%
df.sort_values(['salary','salary_currency'])
# Out:
#      Unnamed: 0  work_year experience_level employment_type        job_title  \
# 185         185       2021               MI              FT    Data Engineer
# 238         238       2021               EN              FT   Data Scientist
# 15           15       2020               MI              FT     Data Analyst
# 124         124       2021               EN              PT     Data Analyst
# 196         196       2021               EN              FT  BI Data Analyst
# ..          ...        ...              ...             ...              ...
# 136         136       2021               MI              FT      ML Engineer
# 137         137       2021               MI              FT      ML Engineer
# 7             7       2020               MI              FT   Data Scientist
# 102         102       2021               MI              FT  BI Data Analyst
# 177         177       2021               MI              FT   Data Scientist
#
# ...

# %%
df[(df['experience_level'] == 'SE')&(df[salary_currency] == 'USD' )]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9ae355791e96> in <module>
# ----> 1 df[(df['experience_level'] == 'SE')&(df[salary_currency] == 'USD' )]
#
# NameError: name 'salary_currency' is not defined

# %%
df.groupby(['experience_level', 'salary']).mean()
# Out:
#                           Unnamed: 0  work_year  salary_in_usd  remote_ratio
# experience_level salary
# EN               4000          238.0     2021.0         4000.0           0.0
#                  8760          124.0     2021.0        10354.0          50.0
#                  9272          196.0     2021.0         9272.0         100.0
#                  10000         279.5     2021.0        10000.0         100.0
#                  12000         104.5     2021.0        12000.0         100.0
# ...                              ...        ...            ...           ...
# SE               1799997       197.0     2021.0        24342.0         100.0
#                  3000000       129.0     2021.0        40570.0          50.0
#                  4000000       198.0     2021.0        54094.0          50.0
#                  4900000       263.0     2021.0        66265.0           0.0
#                  7000000       285.0     2021.0        94665.0          50.0
#
# ...

# %%
df.groupby(['experience_level', 'salary']).max()
# Out:
#                           Unnamed: 0  work_year employment_type  \
# experience_level salary
# EN               4000            238       2021              FT
#                  8760            124       2021              PT
#                  9272            196       2021              FT
#                  10000           521       2022              FT
#                  12000           113       2021              PT
# ...                              ...        ...             ...
# SE               1799997         197       2021              FT
#                  3000000         129       2021              FT
#                  4000000         198       2021              FT
#                  4900000         263       2021              FT
#                  7000000         285       2021              FT
#
#                                           job_title salary_currency  \
# experience_level salary
# EN               4000                Data Scientist             USD
# ...

# %%
df.groupby('experience_level').max()
# Out:
#                   Unnamed: 0  work_year employment_type  \
# experience_level
# EN                       601       2022              PT
# EX                       483       2022              FT
# MI                       606       2022              PT
# SE                       605       2022              FT
#
#                                  job_title    salary salary_currency  \
# experience_level
# EN                      Research Scientist   4450000             USD
# EX                Principal Data Scientist   6000000             USD
# MI                      Research Scientist  30400000             USD
# SE                    Staff Data Scientist   7000000             USD
#
#                   salary_in_usd employee_residence  remote_ratio  \
# experience_level
# EN                       250000                 VN           100
# EX                       600000                 US           100
# MI                       450000                 VN           100
# ...
