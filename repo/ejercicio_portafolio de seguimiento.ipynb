# %% [markdown]
# Antes de inciar recuerda instalar la librería yfinance

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %% [markdown]
# Puedes importar más de una acción en una sola línea de código

# %%
data = yf.download("SPY AAPL MSFT TSLA", start="2019-01-01", end="2021-10-20")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data.head()
# Out:
#             Adj Close                                        Close  \
#                  AAPL       MSFT         SPY       TSLA       AAPL
# Date
# 2019-01-02  38.382225  97.961311  238.694534  62.023998  39.480000
# 2019-01-03  34.559071  94.357521  232.998627  60.071999  35.547501
# 2019-01-04  36.034374  98.746017  240.803085  63.537998  37.064999
# 2019-01-07  35.954166  98.871941  242.701691  66.991997  36.982498
# 2019-01-08  36.639576  99.588844  244.981979  67.070000  37.687500
#
#                                                     High              ...  \
#                   MSFT         SPY       TSLA       AAPL        MSFT  ...
# Date                                                                  ...
# 2019-01-02  101.120003  250.179993  62.023998  39.712502  101.750000  ...
# 2019-01-03   97.400002  244.210007  60.071999  36.430000  100.190002  ...
# 2019-01-04  101.930000  252.389999  63.537998  37.137501  102.510002  ...
# ...

# %% [markdown]
# **Puedes extraer información fundamental con diferentes métodos**
#
# Recuerda consultar la documentación de la librería para concoer todo su potencial

# %%
aapl = yf.Ticker("AAPL")

# %%
# Obten la información de la acción
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 147000,
# ...

# %%
import pandas as pd

# %%
aaplInfo = pd.json_normalize(aapl.info)

# %%
aaplInfo
# Out:
#      zip      sector  fullTimeEmployees  \
# 0  95014  Technology             147000
#
#                                  longBusinessSummary       city         phone  \
# 0  Apple Inc. designs, manufactures, and markets ...  Cupertino  408-996-1010
#
#   state        country companyOfficers               website  ...  \
# 0    CA  United States              []  http://www.apple.com  ...
#
#    fiveYearAvgDividendYield fiftyTwoWeekLow     bid  tradeable  dividendYield  \
# 0                      1.24          107.32  148.45      False         0.0059
#
#    bidSize  dayHigh  regularMarketPrice  preMarketPrice  \
# 0     2900   150.18              148.69            None
#
#                               logo_url
# 0  https://logo.clearbit.com/apple.com
#
# [1 rows x 152 columns]

# %%
aaplInfo['floatShares']
# Out:
# 0    16512974627
# Name: floatShares, dtype: int64

# %%
# Ver estados Financieros
aapl.financials
# Out:
#                                             2020-09-26      2019-09-28  \
# Research Development                     18752000000.0   16217000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        67091000000.0   65737000000.0
# Minority Interest                                 None            None
# Net Income                               57411000000.0   55256000000.0
# Selling General Administrative           19916000000.0   18245000000.0
# Gross Profit                            104956000000.0   98392000000.0
# Ebit                                     66288000000.0   63930000000.0
# Operating Income                         66288000000.0   63930000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2873000000.0   -3576000000.0
# Extraordinary Items                               None            None
# ...

# %%
# Ver Noticias 
aapl.news
# Out:
# [{'uuid': '222203b9-e0a1-3123-bcdd-175492482282',
#   'title': 'Dow Jones Futures: Apple, Microsoft Lead 7 Stocks In Earnings Wave; Will Trump Stock DWAC Keep Rising?',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/222203b9-e0a1-3123-bcdd-175492482282/dow-jones-futures%3A-apple%2C.html',
#   'providerPublishTime': 1635014455,
#   'type': 'STORY'},
#  {'uuid': '33f08797-3feb-388d-88d5-6c25fd494677',
#   'title': 'Jim Rogers: Next bear market will be ‘the worst in my lifetime’ — here are 3 keys to survive it',
#   'publisher': 'MoneyWise',
#   'link': 'https://finance.yahoo.com/news/jim-rogers-next-bear-market-130000779.html',
#   'providerPublishTime': 1634995320,
#   'type': 'STORY'},
#  {'uuid': '40e26144-cf10-38f7-93a6-ea6e2bc4117f',
#   'title': '3 Top Stocks to Buy in 2021 and Hold for the Next Decade',
#   'publisher': 'Motley Fool',
# ...

# %%
pd.json_normalize(aapl.news)
# Out:
#                                    uuid  \
# 0  222203b9-e0a1-3123-bcdd-175492482282
# 1  33f08797-3feb-388d-88d5-6c25fd494677
# 2  40e26144-cf10-38f7-93a6-ea6e2bc4117f
# 3  f7e83b7f-2fe7-3838-a12e-5ab44b6bb2d9
# 4  e9d01710-f8c1-3c21-b661-73928d50a0b5
# 5  382923ee-5ac6-3167-a811-f7a40e2436e9
# 6  c50abc54-5c79-3edc-9fa4-a3b0e037c7ed
# 7  f5dfc21b-099b-3806-a662-a66c0558a53c
#
#                                                title  \
# 0  Dow Jones Futures: Apple, Microsoft Lead 7 Sto...
# 1  Jim Rogers: Next bear market will be ‘the wors...
# 2  3 Top Stocks to Buy in 2021 and Hold for the N...
# 3  Investing in This ETF Right Now Could Make You...
# 4  Epic Games opposes Apple's effort to pause ant...
# 5  Why Magnite, The Trade Desk, and Other Ad-Tech...
# 6  Why Shares of DoubleVerify Surged 14% Higher T...
# 7  Tech giants' earnings may be another test for ...
#
#                    publisher  \
# 0  Investor's Business Daily
# 1                  MoneyWise
# ...
