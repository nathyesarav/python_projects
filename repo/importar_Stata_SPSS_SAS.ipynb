# %%
import pandas as pd

# %% [markdown]
# iniciemos con un archivo de ejemplo qeu provee Stata sobre gastos de hogares en méxico.

# %%
dtafile = 'gastospersona.dta'

DTAdf = pd.read_stata(dtafile)
DTAdf.head()
# Out:
#      folioviv foliohog numren clave tipo_gasto mes_dia frec_rem inst  \
# 0  0100003802        1     02  J002         G4    0000        9
# 1  0100068004        1     05  A202         G4    1108        6
# 2  0100068004        1     05  A202         G4    1109        6
# 3  0100068004        1     05  A202         G4    1110        6
# 4  0100068004        1     05  A202         G4    1111        6
#
#   forma_pag1 forma_pag2 forma_pag3  inscrip  colegia  material  cantidad  \
# 0         00         00         00      NaN      NaN       NaN       NaN
# 1         00         00         00      NaN      NaN       NaN       1.0
# 2         00         00         00      NaN      NaN       NaN       1.0
# 3         00         00         00      NaN      NaN       NaN       1.0
# 4         00         00         00      NaN      NaN       NaN       1.0
#
#    gasto    costo  gasto_tri  gasto_nm  gas_nm_tri
# 0    NaN  35000.0        NaN   35000.0    34239.13
# ...

# %%
DTAdf
# Out:
#           folioviv foliohog numren clave tipo_gasto mes_dia frec_rem inst  \
# 0       0100003802        1     02  J002         G4    0000        9
# 1       0100068004        1     05  A202         G4    1108        6
# 2       0100068004        1     05  A202         G4    1109        6
# 3       0100068004        1     05  A202         G4    1110        6
# 4       0100068004        1     05  A202         G4    1111        6
# ...            ...      ...    ...   ...        ...     ...      ...  ...
# 377008  3260801214        1     01  B004         G1    0823
# 377009  3260801218        1     01  B004         G1    0824
# 377010  3260801218        1     01  B004         G1    0823
# 377011  3260801218        1     01  B004         G1    0821
# 377012  3260801323        1     01  B004         G1    0902
#
#        forma_pag1 forma_pag2 forma_pag3  inscrip  colegia  material  cantidad  \
# 0              00         00         00      NaN      NaN       NaN       NaN
# ...

# %%
DTAdf.dtypes
# Out:
# folioviv       object
# foliohog       object
# numren         object
# clave          object
# tipo_gasto     object
# mes_dia        object
# frec_rem       object
# inst           object
# forma_pag1     object
# forma_pag2     object
# forma_pag3     object
# inscrip       float64
# colegia       float64
# material      float64
# cantidad      float64
# gasto         float64
# costo         float64
# gasto_tri     float64
# gasto_nm      float64
# gas_nm_tri    float64
# dtype: object

# %% [markdown]
# Pasemos ahora a los archivos de SAS - Este es un ejemplo muy sencillo de una tabla

# %%
SASdf = pd.read_sas('sales.sas7bdat')

# %%
SASdf.head()
# Out:
#      YEAR     P           S
# 0  1950.0  12.9  181.899994
# 1  1951.0  11.9  245.000000
# 2  1952.0  10.7  250.199997
# 3  1953.0  11.3  265.899994
# 4  1954.0  11.2  248.500000

# %%
SASdf.dtypes
# Out:
# YEAR    float64
# P       float64
# S       float64
# dtype: object

# %% [markdown]
# Por último archivos de SPSS
# Para evitar el error
# Missing optional dependency 'pyreadstat'.  Use pip or conda to install pyreadstat.
# Debes instalar esta librería
#
# Usaremos un ejemplo de ventas de gasolina

# %%
# !pip install pyreadstat

# %%
import pyreadstat

# %%
SPSSdf = pd.read_spss('gasoline_sales.sav')

# %%
SPSSdf
# Out:
#     week  sales
# 0    1.0   17.0
# 1    2.0   21.0
# 2    3.0   19.0
# 3    4.0   23.0
# 4    5.0   18.0
# 5    6.0   16.0
# 6    7.0   20.0
# 7    8.0   18.0
# 8    9.0   22.0
# 9   10.0   20.0
# 10  11.0   15.0
# 11  12.0   22.0

# %%
SPSSdf.dtypes
# Out:
# week     float64
# sales    float64
# dtype: object
