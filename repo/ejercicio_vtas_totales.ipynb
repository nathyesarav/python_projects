# %%
import pandas as pd

# %%
tabla = pd.read_csv('C:/Users/n_sar/OneDrive/Escritorio/ventasTotales.csv', skiprows=5,sep=';')

# %%
tabla.shape[1]
# Out:
# 7

# %%
tabla.shape
# Out:
# (460, 7)

# %%
tabla.head(3)
# Out:
#       Fecha          Vendedor Región          Artículo    Categoría  Unidades  \
# 0  1/1/2016      Steve Ashton  Norte  Medias Femeninas   Vestimenta         6
# 1  1/1/2016  Trevor Snodgrass  Oeste         Chocolate  Comestibles         8
# 2  1/1/2016        Sarah Bond    Sur            Gorras   Vestimenta         3
#
#   Ganancia
# 0    18,00
# 1     3,84
# 2     6,30

# %%
tabla.tail()
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 455         6    16,50
# 456        11   115,50
# 457         4     6,40
# 458         8     6,80
# 459         7     2,10

# %%
tabla.tail(10)
# Out:
#          Fecha          Vendedor Región           Artículo    Categoría  \
# 450  31/1/2016    Boris Stanford   Este          Chocolate  Comestibles
# 451  31/1/2016      Steve Ashton  Norte         Detergente        Hogar
# 452  31/1/2016        Dustin Gee  Oeste          Caramelos  Comestibles
# 453  31/1/2016        Sarah Bond  Norte           Bombilla        Hogar
# 454  31/1/2016        Dustin Gee  Oeste      Limpiavidrios        Hogar
# 455  31/1/2016        Sarah Bond    Sur            Bufanda   Vestimenta
# 456  31/1/2016        Dustin Gee   Este          Sandalias   Vestimenta
# 457  31/1/2016        Dustin Gee   Este  Sánguche de Queso  Comestibles
# 458  31/1/2016        Dustin Gee  Norte         Escobillón        Hogar
# 459  31/1/2016  Trevor Snodgrass    Sur          Pepinillo  Comestibles
#
#      Unidades Ganancia
# 450         3     1,44
# 451        14    34,72
# 452         6     3,60
# 453         4     2,40
# 454        13    10,40
# 455         6    16,50
# ...

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      460 non-null    object
#  1   Vendedor   460 non-null    object
#  2   Región     460 non-null    object
#  3   Artículo   460 non-null    object
#  4   Categoría  460 non-null    object
#  5   Unidades   460 non-null    int64
#  6   Ganancia   460 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 25.3+ KB

# %%
tabla.Vendedor.value_counts()
# Out:
# Sarah Bond          86
# Steve Ashton        84
# Desmond Delaney     76
# Trevor Snodgrass    75
# Dustin Gee          70
# Boris Stanford      69
# Name: Vendedor, dtype: int64

# %%
tabla.Ganancia.value_counts()
# Out:
# 6,00     13
# 3,20     11
# 4,80     11
# 2,40     10
# 4,20     10
#          ..
# 33,75     1
# 72,00     1
# 22,40     1
# 2,55      1
# 9,35      1
# Name: Ganancia, Length: 173, dtype: int64

# %%
tabla.Unidades.value_counts()
# Out:
# 12    39
# 5     38
# 6     37
# 9     36
# 7     35
# 8     34
# 2     33
# 4     31
# 10    28
# 14    28
# 3     27
# 15    26
# 13    24
# 1     22
# 11    22
# Name: Unidades, dtype: int64

# %%
tabla.Región.value_counts(ascending=True)
# Out:
# Norte    100
# Oeste    102
# Sur      120
# Este     138
# Name: Región, dtype: int64

# %%
tabla.sort_values(by=['Vendedor','Ganancia'])
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 93    6/1/2016    Boris Stanford  Norte   Chocolate  Comestibles         2
# 450  31/1/2016    Boris Stanford   Este   Chocolate  Comestibles         3
# 259  18/1/2016    Boris Stanford    Sur   Pepinillo  Comestibles         5
# 25    2/1/2016    Boris Stanford   Este         Pan  Comestibles         4
# 64    5/1/2016    Boris Stanford    Sur         Pan  Comestibles         4
# ..         ...               ...    ...         ...          ...       ...
# 231  15/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         4
# 314  21/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 328  22/1/2016  Trevor Snodgrass  Oeste    Bombilla        Hogar        14
# 69    5/1/2016  Trevor Snodgrass  Norte  Calcetines   Vestimenta         4
# 238  16/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         2
#
#     Ganancia
# 93      0,96
# 450     1,44
# 259     1,50
# ...

# %%
tabla.Vendedor.sort_values()
# Out:
# 198      Boris Stanford
# 71       Boris Stanford
# 66       Boris Stanford
# 259      Boris Stanford
# 64       Boris Stanford
#              ...
# 212    Trevor Snodgrass
# 209    Trevor Snodgrass
# 206    Trevor Snodgrass
# 286    Trevor Snodgrass
# 459    Trevor Snodgrass
# Name: Vendedor, Length: 460, dtype: object

# %%
tabla[(tabla.Artículo == 'Gorras') &(tabla.Región == 'Norte')]
# Out:
#          Fecha          Vendedor Región Artículo   Categoría  Unidades  \
# 85    6/1/2016        Sarah Bond  Norte   Gorras  Vestimenta         9
# 156  10/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         7
# 159  11/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         2
# 201  14/1/2016   Desmond Delaney  Norte   Gorras  Vestimenta         5
# 360  25/1/2016      Steve Ashton  Norte   Gorras  Vestimenta         7
# 368  26/1/2016    Boris Stanford  Norte   Gorras  Vestimenta         7
# 394  27/1/2016      Steve Ashton  Norte   Gorras  Vestimenta        14
# 396  27/1/2016  Trevor Snodgrass  Norte   Gorras  Vestimenta         3
#
#     Ganancia
# 85     18,90
# 156    14,70
# 159     4,20
# 201    10,50
# 360    14,70
# 368    14,70
# 394    29,40
# 396     6,30

# %%
tabla[tabla.Vendedor.str.contains('Trevor')]
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 1     1/1/2016  Trevor Snodgrass  Oeste   Chocolate  Comestibles         8
# 5     1/1/2016  Trevor Snodgrass   Este     Cerveza  Comestibles        15
# 8     1/1/2016  Trevor Snodgrass   Este         Pan  Comestibles        12
# 10    1/1/2016  Trevor Snodgrass    Sur         Pan  Comestibles         6
# 12    1/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         6
# ..         ...               ...    ...         ...          ...       ...
# 437  30/1/2016  Trevor Snodgrass   Este  Calcetines   Vestimenta        10
# 440  30/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         6
# 442  31/1/2016  Trevor Snodgrass   Este   Sandalias   Vestimenta         6
# 446  31/1/2016  Trevor Snodgrass  Oeste    Sudadera   Vestimenta         2
# 459  31/1/2016  Trevor Snodgrass    Sur   Pepinillo  Comestibles         7
#
#     Ganancia
# 1       3,84
# 5       6,00
# 8       4,80
# ...

# %% [markdown]
# Trae todos los vendedores que comienzan con 'T'

# %%
tabla[tabla.Vendedor.str.startswith('T')]
# Out:
#          Fecha          Vendedor Región    Artículo    Categoría  Unidades  \
# 1     1/1/2016  Trevor Snodgrass  Oeste   Chocolate  Comestibles         8
# 5     1/1/2016  Trevor Snodgrass   Este     Cerveza  Comestibles        15
# 8     1/1/2016  Trevor Snodgrass   Este         Pan  Comestibles        12
# 10    1/1/2016  Trevor Snodgrass    Sur         Pan  Comestibles         6
# 12    1/1/2016  Trevor Snodgrass    Sur      Shorts   Vestimenta         6
# ..         ...               ...    ...         ...          ...       ...
# 437  30/1/2016  Trevor Snodgrass   Este  Calcetines   Vestimenta        10
# 440  30/1/2016  Trevor Snodgrass   Este      Gorras   Vestimenta         6
# 442  31/1/2016  Trevor Snodgrass   Este   Sandalias   Vestimenta         6
# 446  31/1/2016  Trevor Snodgrass  Oeste    Sudadera   Vestimenta         2
# 459  31/1/2016  Trevor Snodgrass    Sur   Pepinillo  Comestibles         7
#
#     Ganancia
# 1       3,84
# 5       6,00
# 8       4,80
# ...

# %%
ali = tabla[tabla.Categoría == 'Comestibles']
ali.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
# 5  1/1/2016  Trevor Snodgrass   Este            Cerveza  Comestibles
# 6  1/1/2016    Boris Stanford  Norte          Pepinillo  Comestibles
#
#    Unidades Ganancia
# 1         8     3,84
# 3         9    14,40
# 4        14     6,72
# 5        15     6,00
# 6        14     4,20

# %% [markdown]
# MATPLOLIB

# %%
import plotly.graph_objects as go

# %%
# %matplotlib inline

# %%
ali.Artículo.value_counts().plot(kind='line', color='orange');

# %% [markdown]
# Gráfico de Barras

# %%
ali.Artículo.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Gráfico Horizontales:

# %%
ali.Artículo.value_counts().plot(kind='barh', color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Gráfico Circular:

# %%
ali.Artículo.value_counts().plot(kind='pie');

# %% [markdown]
# Gráfico Circular:

# %%
ali.Artículo.value_counts().plot(kind='line', color='green', figsize=(10,5));

# %%
ali.Artículo.value_counts().plot(kind='pie');

# %%
ali.Artículo.value_counts().plot(kind='pie', colormap='ocean');

# %%
ali.Artículo.value_counts().plot(kind='pie', colormap='twilight');

# %%
ali.Artículo.value_counts().plot(kind='pie', colormap='jet');

# %%
ali.Artículo.value_counts().plot(kind='line', figsize(10,5));
# Out:
#   File "<ipython-input-94-f9d2d0203a02>", line 1
#     ali.Artículo.value_counts().plot(kind='line', figsize(10,5));
#                                                    ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# Indexación

# %%
type(tabla.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
tabla.set_index('Vendedor',inplace=True)

# %%
tabla.head()
# Out:
#                      Fecha Región           Artículo    Categoría  Unidades  \
# Vendedor
# Steve Ashton      1/1/2016  Norte   Medias Femeninas   Vestimenta         6
# Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles         8
# Sarah Bond        1/1/2016    Sur             Gorras   Vestimenta         3
# Desmond Delaney   1/1/2016    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles        14
#
#                  Ganancia
# Vendedor
# Steve Ashton        18,00
# Trevor Snodgrass     3,84
# Sarah Bond           6,30
# Desmond Delaney     14,40
# Desmond Delaney      6,72

# %%
ven = tabla.reset_index('Vendedor')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dcd2b12c0212> in <module>
# ----> 1 ven = tabla.reset_index('Vendedor')
#
# NameError: name 'tabla' is not defined

# %%
ven.head()
# Out:
#            Vendedor     Fecha Región           Artículo    Categoría  \
# 0      Steve Ashton  1/1/2016  Norte   Medias Femeninas   Vestimenta
# 1  Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles
# 2        Sarah Bond  1/1/2016    Sur             Gorras   Vestimenta
# 3   Desmond Delaney  1/1/2016    Sur  Sánguche de Queso  Comestibles
# 4   Desmond Delaney  1/1/2016   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
ven=tabla.reset_index('Vendedor',inplace=True, ascending=False)

# %%
ven.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-8565cdcf3f2a> in <module>
# ----> 1 ven.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
ven.sort_index('Vendedor',inplace=True)
ven.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0296894bb196> in <module>
# ----> 1 ven.sort_index('Vendedor',inplace=True)
#       2 ven.head()
#
# NameError: name 'ven' is not defined

# %%
tabla.set_index('Vendedor',inplace=True)
tabla.head()
# Out:
#                      Fecha Región           Artículo    Categoría  Unidades  \
# Vendedor
# Steve Ashton      1/1/2016  Norte   Medias Femeninas   Vestimenta         6
# Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles         8
# Sarah Bond        1/1/2016    Sur             Gorras   Vestimenta         3
# Desmond Delaney   1/1/2016    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles        14
#
#                  Ganancia
# Vendedor
# Steve Ashton        18,00
# Trevor Snodgrass     3,84
# Sarah Bond           6,30
# Desmond Delaney     14,40
# Desmond Delaney      6,72

# %%
tabla.loc['Sarah Bond']
# Out:
#                 Fecha Región    Artículo    Categoría  Unidades Ganancia
# Vendedor
# Sarah Bond   1/1/2016    Sur      Gorras   Vestimenta         3     6,30
# Sarah Bond   1/1/2016   Este   Caramelos  Comestibles        15     9,00
# Sarah Bond   2/1/2016  Norte     Bufanda   Vestimenta         4    11,00
# Sarah Bond   2/1/2016   Este      Escoba        Hogar        12    43,80
# Sarah Bond   4/1/2016    Sur  Detergente        Hogar        11    27,28
# ...               ...    ...         ...          ...       ...      ...
# Sarah Bond  29/1/2016   Este      Gorras   Vestimenta         7    14,70
# Sarah Bond  29/1/2016  Oeste  Detergente        Hogar         3     7,44
# Sarah Bond  31/1/2016    Sur  Calcetines   Vestimenta         7    15,75
# Sarah Bond  31/1/2016  Norte    Bombilla        Hogar         4     2,40
# Sarah Bond  31/1/2016    Sur     Bufanda   Vestimenta         6    16,50
#
# [86 rows x 6 columns]

# %%
tabla.reset_index('Vendedor',inplace=True)

# %%
tabla.head()
# Out:
#            Vendedor     Fecha Región           Artículo    Categoría  \
# 0      Steve Ashton  1/1/2016  Norte   Medias Femeninas   Vestimenta
# 1  Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles
# 2        Sarah Bond  1/1/2016    Sur             Gorras   Vestimenta
# 3   Desmond Delaney  1/1/2016    Sur  Sánguche de Queso  Comestibles
# 4   Desmond Delaney  1/1/2016   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
tabla.loc[tabla.Vendedor == 'Sarah Bond']
# Out:
#        Vendedor      Fecha Región    Artículo    Categoría  Unidades Ganancia
# 2    Sarah Bond   1/1/2016    Sur      Gorras   Vestimenta         3     6,30
# 9    Sarah Bond   1/1/2016   Este   Caramelos  Comestibles        15     9,00
# 23   Sarah Bond   2/1/2016  Norte     Bufanda   Vestimenta         4    11,00
# 27   Sarah Bond   2/1/2016   Este      Escoba        Hogar        12    43,80
# 42   Sarah Bond   4/1/2016    Sur  Detergente        Hogar        11    27,28
# ..          ...        ...    ...         ...          ...       ...      ...
# 426  Sarah Bond  29/1/2016   Este      Gorras   Vestimenta         7    14,70
# 427  Sarah Bond  29/1/2016  Oeste  Detergente        Hogar         3     7,44
# 443  Sarah Bond  31/1/2016    Sur  Calcetines   Vestimenta         7    15,75
# 453  Sarah Bond  31/1/2016  Norte    Bombilla        Hogar         4     2,40
# 455  Sarah Bond  31/1/2016    Sur     Bufanda   Vestimenta         6    16,50
#
# [86 rows x 7 columns]

# %%
tabla.iloc[5]
# Out:
# Vendedor     Trevor Snodgrass
# Fecha                1/1/2016
# Región                   Este
# Artículo              Cerveza
# Categoría         Comestibles
# Unidades                   15
# Ganancia                 6,00
# Name: 5, dtype: object

# %%
tabla.iloc[[5,3,100]]
# Out:
#              Vendedor     Fecha Región           Artículo    Categoría  \
# 5    Trevor Snodgrass  1/1/2016   Este            Cerveza  Comestibles
# 3     Desmond Delaney  1/1/2016    Sur  Sánguche de Queso  Comestibles
# 100        Sarah Bond  7/1/2016  Norte         Detergente        Hogar
#
#      Unidades Ganancia
# 5          15     6,00
# 3           9    14,40
# 100         6    14,88

# %%
tabla.iloc[4:15]
# Out:
#             Vendedor     Fecha Región           Artículo    Categoría  \
# 4    Desmond Delaney  1/1/2016   Este          Chocolate  Comestibles
# 5   Trevor Snodgrass  1/1/2016   Este            Cerveza  Comestibles
# 6     Boris Stanford  1/1/2016  Norte          Pepinillo  Comestibles
# 7       Steve Ashton  1/1/2016  Oeste             Gorras   Vestimenta
# 8   Trevor Snodgrass  1/1/2016   Este                Pan  Comestibles
# 9         Sarah Bond  1/1/2016   Este          Caramelos  Comestibles
# 10  Trevor Snodgrass  1/1/2016    Sur                Pan  Comestibles
# 11    Boris Stanford  1/1/2016  Oeste         Calcetines   Vestimenta
# 12  Trevor Snodgrass  1/1/2016    Sur             Shorts   Vestimenta
# 13      Steve Ashton  2/1/2016   Este         Detergente        Hogar
# 14    Boris Stanford  2/1/2016  Norte  Sánguche de Queso  Comestibles
#
#     Unidades Ganancia
# 4         14     6,72
# 5         15     6,00
# 6         14     4,20
# 7          2     4,20
# ...

# %%
type(tabla.groupby('Región'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(tabla.groupby('Región'))
# Out:
# [('Este',
#                Vendedor      Fecha Región           Artículo    Categoría  \
#   4     Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles
#   5    Trevor Snodgrass   1/1/2016   Este            Cerveza  Comestibles
#   8    Trevor Snodgrass   1/1/2016   Este                Pan  Comestibles
#   9          Sarah Bond   1/1/2016   Este          Caramelos  Comestibles
#   13       Steve Ashton   2/1/2016   Este         Detergente        Hogar
#   ..                ...        ...    ...                ...          ...
#   447   Desmond Delaney  31/1/2016   Este           Bombilla        Hogar
#   449    Boris Stanford  31/1/2016   Este           Sudadera   Vestimenta
#   450    Boris Stanford  31/1/2016   Este          Chocolate  Comestibles
#   456        Dustin Gee  31/1/2016   Este          Sandalias   Vestimenta
#   457        Dustin Gee  31/1/2016   Este  Sánguche de Queso  Comestibles
#
#        Unidades Ganancia
#   4          14     6,72
# ...

# %%
for group_key,group_value in tabla.groupby('Región'):
    print(group_key)
    print(group_value)
# Out:
# Este
#              Vendedor      Fecha Región           Artículo    Categoría  \
# 4     Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles
# 5    Trevor Snodgrass   1/1/2016   Este            Cerveza  Comestibles
# 8    Trevor Snodgrass   1/1/2016   Este                Pan  Comestibles
# 9          Sarah Bond   1/1/2016   Este          Caramelos  Comestibles
# 13       Steve Ashton   2/1/2016   Este         Detergente        Hogar
# ..                ...        ...    ...                ...          ...
# 447   Desmond Delaney  31/1/2016   Este           Bombilla        Hogar
# 449    Boris Stanford  31/1/2016   Este           Sudadera   Vestimenta
# 450    Boris Stanford  31/1/2016   Este          Chocolate  Comestibles
# 456        Dustin Gee  31/1/2016   Este          Sandalias   Vestimenta
# 457        Dustin Gee  31/1/2016   Este  Sánguche de Queso  Comestibles
#
#      Unidades Ganancia
# 4          14     6,72
# 5          15     6,00
# 8          12     4,80
# ...

# %%
type(tabla.groupby('Región'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
tabla.groupby('Región').size()
# Out:
# Región
# Este     138
# Norte    100
# Oeste    102
# Sur      120
# dtype: int64

# %%
tabla.groupby(['Región', 'Vendedor','Ganancia']).agg(['min','max','count'])
# Out:
#                                       Fecha                   \
#                                         min        max count
# Región Vendedor         Ganancia
# Este   Boris Stanford   1,44      31/1/2016  31/1/2016     1
#                         1,60       2/1/2016   2/1/2016     1
#                         15,00     11/1/2016  11/1/2016     1
#                         24,50      4/1/2016   4/1/2016     1
#                         24,75     28/1/2016  28/1/2016     1
# ...                                     ...        ...   ...
# Sur    Trevor Snodgrass 4,20      22/1/2016  22/1/2016     1
#                         4,32      11/1/2016  11/1/2016     1
#                         40,15      2/1/2016   2/1/2016     1
#                         7,20      10/1/2016  10/1/2016     1
#                         9,80      16/1/2016  16/1/2016     1
#
#                                           Artículo                          \
# ...

# %%
tabla.groupby(['Región', 'Vendedor','Ganancia']).size()
# Out:
# Región  Vendedor          Ganancia
# Este    Boris Stanford    1,44        1
#                           1,60        1
#                           15,00       1
#                           24,50       1
#                           24,75       1
#                                      ..
# Sur     Trevor Snodgrass  4,20        1
#                           4,32        1
#                           40,15       1
#                           7,20        1
#                           9,80        1
# Length: 427, dtype: int64

# %%
tabla.loc[tabla.Vendedor == 'Sarah Bond'].groupby('Vendedor').agg({'Ganancia': ['min', 'max']})
# Out:
#            Ganancia
#                 min   max
# Vendedor
# Sarah Bond     0,60  9,80

# %%
cat = tabla[(tabla.Vendedor == 'Sarah Bond') & ((tabla.Categoría == 'Vestimenta') | (tabla.Categoría == 'Comestibles'))]
cat
# Out:
#        Vendedor      Fecha Región           Artículo    Categoría  Unidades  \
# 2    Sarah Bond   1/1/2016    Sur             Gorras   Vestimenta         3
# 9    Sarah Bond   1/1/2016   Este          Caramelos  Comestibles        15
# 23   Sarah Bond   2/1/2016  Norte            Bufanda   Vestimenta         4
# 48   Sarah Bond   4/1/2016   Este             Shorts   Vestimenta         2
# 49   Sarah Bond   4/1/2016  Norte             Shorts   Vestimenta        12
# 58   Sarah Bond   4/1/2016   Este            Bufanda   Vestimenta        14
# 62   Sarah Bond   5/1/2016  Norte            Cerveza  Comestibles         3
# 65   Sarah Bond   5/1/2016  Norte                Pan  Comestibles         3
# 85   Sarah Bond   6/1/2016  Norte             Gorras   Vestimenta         9
# 89   Sarah Bond   6/1/2016    Sur            Cerveza  Comestibles        15
# 104  Sarah Bond   7/1/2016   Este         Calcetines   Vestimenta        13
# ...

# %%
c = cat.groupby(['Artículo','Categoría','Región']).size()
c
# Out:
# Artículo           Categoría    Región
# Bufanda            Vestimenta   Este      2
#                                 Norte     1
#                                 Sur       2
# Calcetines         Vestimenta   Este      1
#                                 Norte     2
#                                 Oeste     2
#                                 Sur       1
# Caramelos          Comestibles  Este      1
#                                 Norte     2
# Cerveza            Comestibles  Este      2
#                                 Norte     2
#                                 Sur       1
# Chocolate          Comestibles  Este      1
#                                 Norte     2
#                                 Oeste     1
#                                 Sur       2
# Gorras             Vestimenta   Este      4
#                                 Norte     1
#                                 Sur       1
# Medias Femeninas   Vestimenta   Este      1
# ...

# %%
df = c.unstack('Categoría')
df
# Out:
# Categoría                 Comestibles  Vestimenta
# Artículo          Región
# Bufanda           Este            NaN         2.0
#                   Norte           NaN         1.0
#                   Sur             NaN         2.0
# Calcetines        Este            NaN         1.0
#                   Norte           NaN         2.0
#                   Oeste           NaN         2.0
#                   Sur             NaN         1.0
# Caramelos         Este            1.0         NaN
#                   Norte           2.0         NaN
# Cerveza           Este            2.0         NaN
#                   Norte           2.0         NaN
#                   Sur             1.0         NaN
# Chocolate         Este            1.0         NaN
#                   Norte           2.0         NaN
#                   Oeste           1.0         NaN
#                   Sur             2.0         NaN
# Gorras            Este            NaN         4.0
# ...

# %%
df.stack()
# Out:
# Artículo           Región  Categoría
# Bufanda            Este    Vestimenta     2.0
#                    Norte   Vestimenta     1.0
#                    Sur     Vestimenta     2.0
# Calcetines         Este    Vestimenta     1.0
#                    Norte   Vestimenta     2.0
#                    Oeste   Vestimenta     2.0
#                    Sur     Vestimenta     1.0
# Caramelos          Este    Comestibles    1.0
#                    Norte   Comestibles    2.0
# Cerveza            Este    Comestibles    2.0
#                    Norte   Comestibles    2.0
#                    Sur     Comestibles    1.0
# Chocolate          Este    Comestibles    1.0
#                    Norte   Comestibles    2.0
#                    Oeste   Comestibles    1.0
#                    Sur     Comestibles    2.0
# Gorras             Este    Vestimenta     4.0
#                    Norte   Vestimenta     1.0
#                    Sur     Vestimenta     1.0
# Medias Femeninas   Este    Vestimenta     1.0
# ...

# %%
df.unstack()
# Out:
# Categoría         Comestibles                  Vestimenta
# Región                   Este Norte Oeste  Sur       Este Norte Oeste  Sur
# Artículo
# Bufanda                   NaN   NaN   NaN  NaN        2.0   1.0   NaN  2.0
# Calcetines                NaN   NaN   NaN  NaN        1.0   2.0   2.0  1.0
# Caramelos                 1.0   2.0   NaN  NaN        NaN   NaN   NaN  NaN
# Cerveza                   2.0   2.0   NaN  1.0        NaN   NaN   NaN  NaN
# Chocolate                 1.0   2.0   1.0  2.0        NaN   NaN   NaN  NaN
# Gorras                    NaN   NaN   NaN  NaN        4.0   1.0   NaN  1.0
# Medias Femeninas          NaN   NaN   NaN  NaN        1.0   1.0   NaN  NaN
# Pan                       NaN   2.0   NaN  4.0        NaN   NaN   NaN  NaN
# Pepinillo                 1.0   1.0   1.0  1.0        NaN   NaN   NaN  NaN
# Sandalias                 NaN   NaN   NaN  NaN        NaN   NaN   1.0  1.0
# Shorts                    NaN   NaN   NaN  NaN        3.0   1.0   NaN  NaN
# ...

# %%
df.unstack('Región')
# Out:
# Categoría         Comestibles                  Vestimenta
# Región                   Este Norte Oeste  Sur       Este Norte Oeste  Sur
# Artículo
# Bufanda                   NaN   NaN   NaN  NaN        2.0   1.0   NaN  2.0
# Calcetines                NaN   NaN   NaN  NaN        1.0   2.0   2.0  1.0
# Caramelos                 1.0   2.0   NaN  NaN        NaN   NaN   NaN  NaN
# Cerveza                   2.0   2.0   NaN  1.0        NaN   NaN   NaN  NaN
# Chocolate                 1.0   2.0   1.0  2.0        NaN   NaN   NaN  NaN
# Gorras                    NaN   NaN   NaN  NaN        4.0   1.0   NaN  1.0
# Medias Femeninas          NaN   NaN   NaN  NaN        1.0   1.0   NaN  NaN
# Pan                       NaN   2.0   NaN  4.0        NaN   NaN   NaN  NaN
# Pepinillo                 1.0   1.0   1.0  1.0        NaN   NaN   NaN  NaN
# Sandalias                 NaN   NaN   NaN  NaN        NaN   NaN   1.0  1.0
# Shorts                    NaN   NaN   NaN  NaN        3.0   1.0   NaN  NaN
# ...
