# %%
import pandas as pd

# %%
data_popu=pd.read_csv('C:/Users/n_sar/OneDrive/Escritorio/Nathye/Data Science/Python/AB_NYC_2019.csv')

# %%
data_popu.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data_popu.info
# Out:
# <bound method DataFrame.info of              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
data_popu.shape[1]
# Out:
# 16

# %%
data_popu.shape
# Out:
# (48895, 16)

# %%
data_popu.neighbourhood_group.value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
data_popu.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
data_popu.neighbourhood.value_counts()
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Woodrow                  1
# Richmondtown             1
# Rossville                1
# New Dorp                 1
# Fort Wadsworth           1
# Name: neighbourhood, Length: 221, dtype: int64

# %%
data_popu.sort_values(by=['neighbourhood','price'])
# Out:
#              id                                               name    host_id  \
# 22775  18442048                            Clean-N-Comfy Bronx Pad   25385574
# 33740  26744053                                       Private Room  200933726
# 1167     498120                              Hi Traveler.. welcome    2459648
# 38593  30348636         Quiet, serene Holiday getaway in the Bronx   20444114
# 45758  34941479                         Place to be Private room 2  263266237
# ...         ...                                                ...        ...
# 18436  14499123      Spacious  Home 15 Minutes Away From Manhattan   89523770
# 28483  22088100  Bright and Warm place -\nonly 17min to Central...  161351021
# 10441   7997433  30 Mins to Times Square -Javits Ctr! Awesome f...   42215969
# 29016  22328175    Big room with private bath - close to Manhattan  161351021
# 10131   7771170                           Creative Woodside Studio    8134104
#
# ...

# %%
import seaborn as sns 
sns.countplot(x='price', data=data_popu)
# Out:
# <AxesSubplot:xlabel='price', ylabel='count'>
